# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

df_amostra = pd.read_csv('../arquivos_csv/amostraTreinamento3.csv', low_memory=False)
df_teste = pd.read_csv('../arquivos_csv/teste3.csv', low_memory=False)

X_treino = df_amostra.drop(columns=['Credit_Score'])
y_treino = df_amostra['Credit_Score']

label_encoder = LabelEncoder()
y_treino = label_encoder.fit_transform(y_treino)

# %% [markdown]
# #### C = 0,1

# %%
# Configurar o modelo SVM com C = 0.1
C_value = 0.1
svm_model = SVC(kernel='linear', C=C_value)
svm_model.fit(X_treino, y_treino)

# Fazer previsões no conjunto de teste
y_pred_teste = svm_model.predict(df_teste)
y_pred_teste_labels = label_encoder.inverse_transform(y_pred_teste)

# Exibir as previsões para o df_teste
predicoes_df = pd.DataFrame(y_pred_teste_labels, columns=['Credit_Score_Predito'])
print(f"Previsões para C = {C_value}:")
print(predicoes_df.head())

# Avaliação do modelo no conjunto de treino
y_pred_treino = svm_model.predict(X_treino)
accuracy = accuracy_score(y_treino, y_pred_treino)
conf_matrix = confusion_matrix(y_treino, y_pred_treino)
print(f"Acurácia no conjunto de treino para C = {C_value}: {accuracy:.4f}")

# Exibir matriz de confusão
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.title(f'Matriz de Confusão no Conjunto de Treinamento (C = {C_value})')
plt.show()
# Out:
# Previsões para C = 0.1:
#   Credit_Score_Predito
# 0             Standard
# 1                 Good
# 2                 Good
# 3                 Good
# 4                 Good
# Acurácia no conjunto de treino para C = 0.1: 0.6057

# %% [markdown]
# #### C = 1

# %%
# Configurar o modelo SVM com C = 1
C_value = 1
svm_model = SVC(kernel='linear', C=C_value)
svm_model.fit(X_treino, y_treino)

# Fazer previsões no conjunto de teste
y_pred_teste = svm_model.predict(df_teste)
y_pred_teste_labels = label_encoder.inverse_transform(y_pred_teste)

# Exibir as previsões para o df_teste
predicoes_df = pd.DataFrame(y_pred_teste_labels, columns=['Credit_Score_Predito'])
print(f"Previsões para C = {C_value}:")
print(predicoes_df.head())

# Avaliação do modelo no conjunto de treino
y_pred_treino = svm_model.predict(X_treino)
accuracy = accuracy_score(y_treino, y_pred_treino)
conf_matrix = confusion_matrix(y_treino, y_pred_treino)
print(f"Acurácia no conjunto de treino para C = {C_value}: {accuracy:.4f}")

# Exibir matriz de confusão
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.title(f'Matriz de Confusão no Conjunto de Treinamento (C = {C_value})')
plt.show()
# Out:
# Previsões para C = 1:
#   Credit_Score_Predito
# 0             Standard
# 1                 Good
# 2                 Good
# 3                 Good
# 4                 Good
# Acurácia no conjunto de treino para C = 1: 0.6057

# %% [markdown]
# #### C = 10

# %%
# Configurar o modelo SVM com C = 10
C_value = 10
svm_model = SVC(kernel='linear', C=C_value)
svm_model.fit(X_treino, y_treino)

# Fazer previsões no conjunto de teste
y_pred_teste = svm_model.predict(df_teste)
y_pred_teste_labels = label_encoder.inverse_transform(y_pred_teste)

# Exibir as previsões para o df_teste
predicoes_df = pd.DataFrame(y_pred_teste_labels, columns=['Credit_Score_Predito'])
print(f"Previsões para C = {C_value}:")
print(predicoes_df.head())

# Avaliação do modelo no conjunto de treino
y_pred_treino = svm_model.predict(X_treino)
accuracy = accuracy_score(y_treino, y_pred_treino)
conf_matrix = confusion_matrix(y_treino, y_pred_treino)
print(f"Acurácia no conjunto de treino para C = {C_value}: {accuracy:.4f}")

# Exibir matriz de confusão
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.title(f'Matriz de Confusão no Conjunto de Treinamento (C = {C_value})')
plt.show()

# %% [markdown]
# #### C = 100

# %%
# Configurar o modelo SVM com C = 100
C_value = 100
svm_model = SVC(kernel='linear', C=C_value)
svm_model.fit(X_treino, y_treino)

# Fazer previsões no conjunto de teste
y_pred_teste = svm_model.predict(df_teste)
y_pred_teste_labels = label_encoder.inverse_transform(y_pred_teste)

# Exibir as previsões para o df_teste
predicoes_df = pd.DataFrame(y_pred_teste_labels, columns=['Credit_Score_Predito'])
print(f"Previsões para C = {C_value}:")
print(predicoes_df.head())

# Avaliação do modelo no conjunto de treino
y_pred_treino = svm_model.predict(X_treino)
accuracy = accuracy_score(y_treino, y_pred_treino)
conf_matrix = confusion_matrix(y_treino, y_pred_treino)
print(f"Acurácia no conjunto de treino para C = {C_value}: {accuracy:.4f}")

# Exibir matriz de confusão
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Previsto')
plt.ylabel('Verdadeiro')
plt.title(f'Matriz de Confusão no Conjunto de Treinamento (C = {C_value})')
plt.show()
